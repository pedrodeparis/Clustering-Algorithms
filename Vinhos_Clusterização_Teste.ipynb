# %% [markdown]
# <a href="https://colab.research.google.com/github/pedrodeparis/Clustering-Algorithms/blob/main/Vinhos_Clusteriza%C3%A7%C3%A3o_Teste.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# %pip install kmodes

# %%
# Data wrangling
import numpy as np
import pandas as pd

# Dataviz
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

from yellowbrick.cluster import KElbowVisualizer, SilhouetteVisualizer, InterclusterDistance, kelbow_visualizer, silhouette_visualizer

## -- Machine learning -- ##
from sklearn import datasets
from sklearn.mixture import GaussianMixture
from sklearn.cluster import KMeans, DBSCAN, MeanShift
from sklearn.cluster import k_means, dbscan, mean_shift, estimate_bandwidth
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale

from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster

from kmodes.kmodes import KModes            # clustering categorical data
from kmodes.kprototypes import KPrototypes  # clustering mixed data

# %%
df_wines,_ = datasets.load_wine(as_frame=True, return_X_y=True)
df_wines
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0          3.06                  0.28             2.29             5.64  1.04
# 1          2.76                  0.26             1.28             4.38  1.05
# 2          3.24                  0.30             2.81             5.68  1.03
# 3          3.49                  0.24             2.18             7.80  0.86
# 4          2.69                  0.39             1.82             4.32  1.04
# ..          ...                   ...              ...              ...   ...
# 173        0.61                  0.52             1.06             7.70  0.64
# 174        0.75                  0.43             1.41             7.30  0.70
# 175        0.69                  0.43             1.35            10.20  0.59
# 176        0.68                  0.53             1.46             9.30  0.60
# 177        0.76                  0.56             1.35             9.20  0.61
#
#      od280/od315_of_diluted_wines  proline
# 0                            3.92   1065.0
# 1                            3.40   1050.0
# 2                            3.17   1185.0
# 3                            3.45   1480.0
# 4                            2.93    735.0
# ..                            ...      ...
# 173                          1.74    740.0
# 174                          1.56    750.0
# 175                          1.56    835.0
# 176                          1.62    840.0
# 177                          1.60    560.0
#
# [178 rows x 13 columns]

# %%
df_wines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   alcohol                       178 non-null    float64
#  1   malic_acid                    178 non-null    float64
#  2   ash                           178 non-null    float64
#  3   alcalinity_of_ash             178 non-null    float64
#  4   magnesium                     178 non-null    float64
#  5   total_phenols                 178 non-null    float64
#  6   flavanoids                    178 non-null    float64
#  7   nonflavanoid_phenols          178 non-null    float64
#  8   proanthocyanins               178 non-null    float64
#  9   color_intensity               178 non-null    float64
#  10  hue                           178 non-null    float64
#  11  od280/od315_of_diluted_wines  178 non-null    float64
#  12  proline                       178 non-null    float64
# dtypes: float64(13)
# memory usage: 18.2 KB

# %%
df_wines.duplicated().any()
# Out:
# False

# %%
df_wines.isna().sum().any()
# Out:
# False

# %%
df_wines_scaled = df_wines.apply(scale)

df_wines_scaled.plot.box()
plt.xticks(rotation=60, ha='right');

# %%
outlier_rows = df_wines_scaled.abs().gt(3).any(axis=1)
outlier_rows.sum()
# Out:
# 10

# %%
df_wines_scaled = df_wines_scaled[~outlier_rows]

# %%
kelbow_visualizer(KMeans(), df_wines_scaled, k=11);
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
model = KMeans(4, random_state=0).fit(df_wines_scaled)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
centroids = model.cluster_centers_
labels = model.labels_

# %%
(
  pd.DataFrame(centroids, columns=df_wines_scaled.columns)
  .T.add_prefix('Grupo_')
  .plot.bar(subplots=True, figsize=(12,12), legend=False)
)

plt.xticks(rotation=60, ha='right')
plt.tight_layout()
plt.show()

# %%
centers = pd.DataFrame(centroids, columns=df_wines.columns)
centers
# Out:
#     alcohol  malic_acid       ash  alcalinity_of_ash  magnesium  \
# 0  0.146964    0.937031  0.195499           0.528549  -0.076428
# 1  0.960537   -0.316354  0.309729          -0.774933   0.455725
# 2 -0.974152   -0.395284  0.191113           0.648933  -0.490200
# 3 -0.786132   -0.453349 -0.790481          -0.143883  -0.549105
#
#    total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# 0      -1.026817   -1.237424              0.700397        -0.816473
# 1       0.897698    0.974760             -0.607763         0.563785
# 2      -0.628614   -0.367120              0.797288        -0.495663
# 3       0.265048    0.316454             -0.502648         0.255705
#
#    color_intensity       hue  od280/od315_of_diluted_wines   proline
# 0         0.903750 -1.179659                     -1.296928 -0.398762
# 1         0.241598  0.463243                      0.786065  1.220968
# 2        -0.916222  0.401839                     -0.154359 -0.709675
# 3        -0.806486  0.453388                      0.521338 -0.734021

# %%
fig,axes = plt.subplots(nrows=4, figsize=(14,12), sharex=True)

for i,ax in enumerate(axes):
  center = centers.loc[i,:]
  maxPC = 1.01 * center.abs().max()
  colors = ['green' if l > 0 else 'red' for l in center]
  center.plot.bar(ax=ax, color=colors)
  ax.set_ylabel(f'Cluster {i+1}')
  ax.set_ylim(-maxPC, maxPC)
  ax.axhline(color='gray')
  ax.xaxis.set_ticks_position('none')

plt.xticks(rotation=60, ha='right')
plt.tight_layout()
plt.show()

# %%
(
  df_wines[~outlier_rows].assign(cluster=labels)
  .groupby('cluster')
  .agg(['mean','min','median','max'])
)
# Out:
#            alcohol                       malic_acid                     \
#               mean    min  median    max       mean   min median   max
# cluster
# 0        13.119592  12.20  13.110  14.16   3.380204  1.24  3.300  5.65
# 1        13.778214  12.85  13.765  14.83   1.983929  1.35  1.765  4.04
# 2        12.212000  11.41  12.080  13.49   1.896000  0.74  1.630  4.43
# 3        12.364211  11.45  12.335  13.86   1.831316  0.89  1.520  4.31
#
#               ash        ...    hue       od280/od315_of_diluted_wines        \
#              mean   min  ... median   max                         mean   min
# cluster                  ...
# 0        2.420000  1.98  ...  0.670  0.96                     1.693469  1.27
# 1        2.451250  2.04  ...  1.065  1.28                     3.168214  2.51
# 2        2.418800  2.02  ...  0.980  1.45                     2.502400  1.59
# 3        2.150263  1.70  ...  1.060  1.42                     2.980789  2.14
#
#                           proline
#         median   max         mean    min  median     max
# cluster
# 0        1.680  2.47   621.673469  372.0   620.0   880.0
# 1        3.170  4.00  1130.303571  735.0  1100.0  1680.0
# 2        2.500  3.30   524.040000  315.0   495.0   870.0
# 3        3.035  3.64   516.394737  278.0   479.0  1020.0
#
# [4 rows x 52 columns]

# %%
(
  df_wines[~outlier_rows].assign(cluster=labels)
  .groupby('cluster')
  .mean()
  .transpose()
  .style.background_gradient(cmap='YlOrRd', axis=1)
)
# Out:
# <style type="text/css">
# #T_14e82_row0_col0 {
#   background-color: #fc6430;
#   color: #f1f1f1;
# }
# #T_14e82_row0_col1, #T_14e82_row1_col0, #T_14e82_row2_col1, #T_14e82_row3_col2, #T_14e82_row4_col1, #T_14e82_row5_col1, #T_14e82_row6_col1, #T_14e82_row7_col2, #T_14e82_row8_col1, #T_14e82_row9_col0, #T_14e82_row10_col1, #T_14e82_row11_col1, #T_14e82_row12_col1 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_14e82_row0_col2, #T_14e82_row1_col3, #T_14e82_row2_col3, #T_14e82_row3_col1, #T_14e82_row4_col3, #T_14e82_row5_col0, #T_14e82_row6_col0, #T_14e82_row7_col1, #T_14e82_row8_col0, #T_14e82_row9_col2, #T_14e82_row10_col0, #T_14e82_row11_col0, #T_14e82_row12_col3 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_14e82_row0_col3 {
#   background-color: #fff1ab;
#   color: #000000;
# }
# #T_14e82_row1_col1 {
#   background-color: #fff1a9;
#   color: #000000;
# }
# #T_14e82_row1_col2 {
#   background-color: #fff9be;
#   color: #000000;
# }
# #T_14e82_row2_col0 {
#   background-color: #b20026;
#   color: #f1f1f1;
# }
# #T_14e82_row2_col2 {
#   background-color: #b40026;
#   color: #f1f1f1;
# }
# #T_14e82_row3_col0 {
#   background-color: #a80026;
#   color: #f1f1f1;
# }
# #T_14e82_row3_col3 {
#   background-color: #fd9e43;
#   color: #000000;
# }
# #T_14e82_row4_col0 {
#   background-color: #fd9640;
#   color: #000000;
# }
# #T_14e82_row4_col2, #T_14e82_row9_col3 {
#   background-color: #fff7b7;
#   color: #000000;
# }
# #T_14e82_row5_col2 {
#   background-color: #fee085;
#   color: #000000;
# }
# #T_14e82_row5_col3 {
#   background-color: #f33b25;
#   color: #f1f1f1;
# }
# #T_14e82_row6_col2 {
#   background-color: #fead4a;
#   color: #000000;
# }
# #T_14e82_row6_col3 {
#   background-color: #ed2e21;
#   color: #f1f1f1;
# }
# #T_14e82_row7_col0 {
#   background-color: #a10026;
#   color: #f1f1f1;
# }
# #T_14e82_row7_col3 {
#   background-color: #fff4b2;
#   color: #000000;
# }
# #T_14e82_row8_col2 {
#   background-color: #fedc7c;
#   color: #000000;
# }
# #T_14e82_row8_col3 {
#   background-color: #db141e;
#   color: #f1f1f1;
# }
# #T_14e82_row9_col1 {
#   background-color: #fa4a29;
#   color: #f1f1f1;
# }
# #T_14e82_row10_col2 {
#   background-color: #910026;
#   color: #f1f1f1;
# }
# #T_14e82_row10_col3 {
#   background-color: #820026;
#   color: #f1f1f1;
# }
# #T_14e82_row11_col2 {
#   background-color: #fd7435;
#   color: #f1f1f1;
# }
# #T_14e82_row11_col3 {
#   background-color: #bd0026;
#   color: #f1f1f1;
# }
# #T_14e82_row12_col0 {
#   background-color: #ffe691;
#   color: #000000;
# }
# #T_14e82_row12_col2 {
#   background-color: #fffdc8;
#   color: #000000;
# }
# </style>
# <table id="T_14e82" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >cluster</th>
#       <th id="T_14e82_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_14e82_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_14e82_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_14e82_level0_col3" class="col_heading level0 col3" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14e82_level0_row0" class="row_heading level0 row0" >alcohol</th>
#       <td id="T_14e82_row0_col0" class="data row0 col0" >13.119592</td>
#       <td id="T_14e82_row0_col1" class="data row0 col1" >13.778214</td>
#       <td id="T_14e82_row0_col2" class="data row0 col2" >12.212000</td>
#       <td id="T_14e82_row0_col3" class="data row0 col3" >12.364211</td>
#     </tr>
#     <tr>
#       <th id="T_14e82_level0_row1" class="row_heading level0 row1" >malic_acid</th>
#       <td id="T_14e82_row1_col0" class="data row1 col0" >3.380204</td>
#       <td id="T_14e82_row1_col1" class="data row1 col1" >1.983929</td>
#       <td id="T_14e82_row1_col2" class="data row1 col2" >1.896000</td>
#       <td id="T_14e82_row1_col3" class="data row1 col3" >1.831316</td>
#     </tr>
#     <tr>
#       <th id="T_14e82_level0_row2" class="row_heading level0 row2" >ash</th>
#       <td id="T_14e82_row2_col0" class="data row2 col0" >2.420000</td>
#       <td id="T_14e82_row2_col1" class="data row2 col1" >2.451250</td>
#       <td id="T_14e82_row2_col2" class="data row2 col2" >2.418800</td>
#       <td id="T_14e82_row2_col3" class="data row2 col3" >2.150263</td>
#     </tr>
#     <tr>
#       <th id="T_14e82_level0_row3" class="row_heading level0 row3" >alcalinity_of_ash</th>
#       <td id="T_14e82_row3_col0" class="data row3 col0" >21.255102</td>
#       <td id="T_14e82_row3_col1" class="data row3 col1" >16.914286</td>
#       <td id="T_14e82_row3_col2" class="data row3 col2" >21.656000</td>
#       <td id="T_14e82_row3_col3" class="data row3 col3" >19.015789</td>
#     </tr>
#     <tr>
#       <th id="T_14e82_level0_row4" class="row_heading level0 row4" >magnesium</th>
#       <td id="T_14e82_row4_col0" class="data row4 col0" >98.653061</td>
#       <td id="T_14e82_row4_col1" class="data row4 col1" >106.232143</td>
#       <td id="T_14e82_row4_col2" class="data row4 col2" >92.760000</td>
#       <td id="T_14e82_row4_col3" class="data row4 col3" >91.921053</td>
#     </tr>
#     <tr>
#       <th id="T_14e82_level0_row5" class="row_heading level0 row5" >total_phenols</th>
#       <td id="T_14e82_row5_col0" class="data row5 col0" >1.654286</td>
#       <td id="T_14e82_row5_col1" class="data row5 col1" >2.855357</td>
#       <td id="T_14e82_row5_col2" class="data row5 col2" >1.902800</td>
#       <td id="T_14e82_row5_col3" class="data row5 col3" >2.460526</td>
#     </tr>
#     <tr>
#       <th id="T_14e82_level0_row6" class="row_heading level0 row6" >flavanoids</th>
#       <td id="T_14e82_row6_col0" class="data row6 col0" >0.796735</td>
#       <td id="T_14e82_row6_col1" class="data row6 col1" >3.000179</td>
#       <td id="T_14e82_row6_col2" class="data row6 col2" >1.663600</td>
#       <td id="T_14e82_row6_col3" class="data row6 col3" >2.344474</td>
#     </tr>
#     <tr>
#       <th id="T_14e82_level0_row7" class="row_heading level0 row7" >nonflavanoid_phenols</th>
#       <td id="T_14e82_row7_col0" class="data row7 col0" >0.448776</td>
#       <td id="T_14e82_row7_col1" class="data row7 col1" >0.286429</td>
#       <td id="T_14e82_row7_col2" class="data row7 col2" >0.460800</td>
#       <td id="T_14e82_row7_col3" class="data row7 col3" >0.299474</td>
#     </tr>
#     <tr>
#       <th id="T_14e82_level0_row8" class="row_heading level0 row8" >proanthocyanins</th>
#       <td id="T_14e82_row8_col0" class="data row8 col0" >1.124898</td>
#       <td id="T_14e82_row8_col1" class="data row8 col1" >1.912679</td>
#       <td id="T_14e82_row8_col2" class="data row8 col2" >1.308000</td>
#       <td id="T_14e82_row8_col3" class="data row8 col3" >1.736842</td>
#     </tr>
#     <tr>
#       <th id="T_14e82_level0_row9" class="row_heading level0 row9" >color_intensity</th>
#       <td id="T_14e82_row9_col0" class="data row9 col0" >7.147347</td>
#       <td id="T_14e82_row9_col1" class="data row9 col1" >5.616607</td>
#       <td id="T_14e82_row9_col2" class="data row9 col2" >2.940000</td>
#       <td id="T_14e82_row9_col3" class="data row9 col3" >3.193684</td>
#     </tr>
#     <tr>
#       <th id="T_14e82_level0_row10" class="row_heading level0 row10" >hue</th>
#       <td id="T_14e82_row10_col0" class="data row10 col0" >0.688571</td>
#       <td id="T_14e82_row10_col1" class="data row10 col1" >1.063036</td>
#       <td id="T_14e82_row10_col2" class="data row10 col2" >1.049040</td>
#       <td id="T_14e82_row10_col3" class="data row10 col3" >1.060789</td>
#     </tr>
#     <tr>
#       <th id="T_14e82_level0_row11" class="row_heading level0 row11" >od280/od315_of_diluted_wines</th>
#       <td id="T_14e82_row11_col0" class="data row11 col0" >1.693469</td>
#       <td id="T_14e82_row11_col1" class="data row11 col1" >3.168214</td>
#       <td id="T_14e82_row11_col2" class="data row11 col2" >2.502400</td>
#       <td id="T_14e82_row11_col3" class="data row11 col3" >2.980789</td>
#     </tr>
#     <tr>
#       <th id="T_14e82_level0_row12" class="row_heading level0 row12" >proline</th>
#       <td id="T_14e82_row12_col0" class="data row12 col0" >621.673469</td>
#       <td id="T_14e82_row12_col1" class="data row12 col1" >1130.303571</td>
#       <td id="T_14e82_row12_col2" class="data row12 col2" >524.040000</td>
#       <td id="T_14e82_row12_col3" class="data row12 col3" >516.394737</td>
#     </tr>
#   </tbody>
# </tab

# %%
silhouette_score(df_wines_scaled[~outlier_rows], labels)
# Out:
# <ipython-input-18-cb769b07a8aa>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   silhouette_score(df_wines_scaled[~outlier_rows], labels)
# 0.24989859662052233
